# %%
import os

# %%
os.getenv
# Out:
# <function os.getenv(key, default=None)>

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_excel("nfl.xlsx")

# %%
df.set_index("Date", inplace=True)

# %%
df.head()
# Out:
#                       Home Team             Away Team  Home Score  Away Score  \
# Date
# 2020-10-05    Green Bay Packers       Atlanta Falcons          30          16
# 2020-10-05   Kansas City Chiefs  New England Patriots          26          10
# 2020-10-04  San Francisco 49ers   Philadelphia Eagles          20          25
# 2020-10-04    Las Vegas Raiders         Buffalo Bills          23          30
# 2020-10-04     Los Angeles Rams       New York Giants          17           9
#
#            Overtime? Playoff Game? Neutral Venue?  Home Odds Open  \
# Date
# 2020-10-05       NaN           NaN            NaN            1.29
# 2020-10-05       NaN           NaN            NaN            1.31
# 2020-10-04       NaN           NaN            NaN            1.37
# 2020-10-04       NaN           NaN            NaN            2.25
# 2020-10-04       NaN           NaN            NaN            1.16
#
#             Home Odds Min  Home Odds Max  ...  Total Score Close  \
# ...

# %%
years = df.loc["2018":"2020"]

# %%
something = pd.read_html("https://en.wikipedia.org/wiki/List_of_current_National_Football_League_stadiums")

# %%
something[3]
# Out:
#                         Stadium  Capacity           Location Surface  \
# 0  Future Buffalo Bills stadium       NaN  Buffalo, New York   Grass
# 1     Future Washington Stadium   60000.0                NaN     NaN
#
#   Roof type                   Team(s)  Opening  Ref(s)
# 0      Open             Buffalo Bills      NaN     NaN
# 1      Open  Washington Football Team      NaN     NaN

# %%
something[2]
# Out:
#    Image                          Stadium      Capacity             Location  \
# 0    NaN                Allegiant Stadium         65000     Paradise, Nevada
# 1    NaN                   Estadio Azteca    87,523[43]  Mexico City, Mexico
# 2    NaN  Tom Benson Hall of Fame Stadium         22364         Canton, Ohio
# 3    NaN                  Wembley Stadium  86,000[nb 3]      London, England
# 4    NaN        Tottenham Hotspur Stadium         62062      London, England
#
#                 Surface              Roof type           Event(s)      Opened  \
# 0         Bermuda grass                  Fixed           Pro Bowl        2020
# 1                 Grass                   Open    NFL Mexico Game        1966
# 2  FieldTurf Classic HD                   Open  Hall of Fame Game  1938[nb 2]
# 3     Desso GrassMaster  Partially retractable   NFL London Games        2007
# 4       Artificial turf                   Open   NFL London Games        2019
#
#   Ref(s)
# 0    [3]
# 1    NaN
# ...

# %%
years[["Home Team", "Away Team"]]
# Out:
#                            Home Team                 Away Team
# Date
# 2020-10-05         Green Bay Packers           Atlanta Falcons
# 2020-10-05        Kansas City Chiefs      New England Patriots
# 2020-10-04       San Francisco 49ers       Philadelphia Eagles
# 2020-10-04         Las Vegas Raiders             Buffalo Bills
# 2020-10-04          Los Angeles Rams           New York Giants
# 2020-10-04         Carolina Panthers         Arizona Cardinals
# 2020-10-04             Chicago Bears        Indianapolis Colts
# 2020-10-04        Cincinnati Bengals      Jacksonville Jaguars
# 2020-10-04            Dallas Cowboys          Cleveland Browns
# 2020-10-04             Detroit Lions        New Orleans Saints
# 2020-10-04            Houston Texans         Minnesota Vikings
# 2020-10-04            Miami Dolphins          Seattle Seahawks
# 2020-10-04      Tampa Bay Buccaneers      Los Angeles Chargers
# 2020-10-04  Washington Football Team          Baltimore Ravens
# ...

# %%
years["Home Team"]
# Out:
# Date
# 2020-10-05           Green Bay Packers
# 2020-10-05          Kansas City Chiefs
# 2020-10-04         San Francisco 49ers
# 2020-10-04           Las Vegas Raiders
# 2020-10-04            Los Angeles Rams
# 2020-10-04           Carolina Panthers
# 2020-10-04               Chicago Bears
# 2020-10-04          Cincinnati Bengals
# 2020-10-04              Dallas Cowboys
# 2020-10-04               Detroit Lions
# 2020-10-04              Houston Texans
# 2020-10-04              Miami Dolphins
# 2020-10-04        Tampa Bay Buccaneers
# 2020-10-04    Washington Football Team
# 2020-10-01               New York Jets
# 2020-09-28            Baltimore Ravens
# 2020-09-27          New Orleans Saints
# 2020-09-27           Arizona Cardinals
# 2020-09-27              Denver Broncos
# 2020-09-27            Seattle Seahawks
# 2020-09-27          Indianapolis Colts
# 2020-09-27        Los Angeles Chargers
# 2020-09-27             Atlanta Falcons
# 2020-09-27               Buffalo Bills
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
years["Stadium"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Stadium'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-b1025eb5572b> in <module>
# ----> 1 years["Stadium"]
#
# ...

# %%
san_fran = years.loc[(years["Home Team"] == "San Francisco 49ers") | (years["Away Team"] == "San Francisco 49ers")]
san_fran=san_fran[["Home Team", "Away Team", "Home Score", "Away Score", "Total Score Open", "Home Line Open","Away Line Open" ]]

# %% [markdown]
# weather<br>
# condition<br>
# dummy variable's
